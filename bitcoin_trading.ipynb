# %% [markdown]
# # BTC ML/DL Trading strategy

# %%
from src.Utils import *

# %%
df = pq.read_pandas(source=f"assets/parquet/{Utils.get_asset_id('Bitcoin')}.parquet").to_pandas()

# %%
df
# Out:
#                      Count          Open     High       Low         Close  \
# timestamp
# 2018-01-01 00:01:00    229  13835.194000  14013.8  13666.11  13850.176000
# 2018-01-01 00:02:00    235  13835.036000  14052.3  13680.00  13828.102000
# 2018-01-01 00:03:00    528  13823.900000  14000.4  13601.00  13801.314000
# 2018-01-01 00:04:00    435  13802.512000  13999.0  13576.28  13768.040000
# 2018-01-01 00:05:00    742  13766.000000  13955.9  13554.44  13724.914000
# ...                    ...           ...      ...       ...           ...
# 2022-01-23 23:56:00   1221  36278.361667  36331.0  36249.00  36293.123333
# 2022-01-23 23:57:00   1634  36289.681667  36328.0  36230.72  36261.708333
# 2022-01-23 23:58:00   1570  36262.841667  36319.0  36230.30  36276.223333
# 2022-01-23 23:59:00   1459  36268.849570  36313.0  36231.71  36276.623333
# 2022-01-24 00:00:00   2917  36262.038571  36302.0  36176.45  36221.987143
#
#                          Volume          VWAP
# timestamp
# ...

# %%
df = pq.read_pandas(source=f"assets/parquet/ALL.parquet").to_pandas()

# %%
df
# Out:
#                      Asset_ID  Count         Open          High           Low  \
# timestamp
# 2018-01-01 00:01:00         2     40   2376.58000   2399.500000   2357.140000
# 2018-01-01 00:01:00         0      5      8.53000      8.530000      8.530000
# 2018-01-01 00:01:00         1    229  13835.19400  14013.800000  13666.110000
# 2018-01-01 00:01:00         5     32      7.65960      7.659600      7.656700
# 2018-01-01 00:01:00         7      5     25.92000     25.920000     25.874000
# ...                       ...    ...          ...           ...           ...
# 2022-01-24 00:00:00         9    214    112.29300    112.470000    111.840000
# 2022-01-24 00:00:00        10     25   1833.56500   1834.700000   1831.050000
# 2022-01-24 00:00:00        13    235      0.05752      0.057618      0.057389
# 2022-01-24 00:00:00        12    492      0.20094      0.201066      0.199352
# 2022-01-24 00:00:00        11     40    156.76400    156.930000    156.200000
#
# ...
